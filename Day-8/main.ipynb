# %%
import sqlite3
import pandas as pd
import folium
from pyproj import Transformer

# --- 1. Extraction  ---
query = """
SELECT
    c.first_name, c.last_name, b.nice_score,
    ci.name AS city,
    ep.x_m AS elf_x, ep.y_m AS elf_y
FROM behavior b
JOIN children c ON b.child_id = c.id
JOIN households h ON c.household_id = h.id
JOIN cities ci ON h.city_id = ci.id
JOIN elf_plan ep ON c.id = ep.child_id
WHERE b.year = 2025
ORDER BY b.nice_score DESC
LIMIT 3;
"""

with sqlite3.connect('kids.db') as conn:
    df = pd.read_sql_query(query, conn)

# --- 2. Transformation Vectorisée  ---
transformer = Transformer.from_crs("EPSG:3857", "EPSG:4326")

df['latitude'], df['longitude'] = transformer.transform(df['elf_x'].values, df['elf_y'].values)

print("------------- 🏆 TOP 3 KIDS 2025 -------------")
display(df[['first_name', 'city', 'latitude', 'longitude']])

# --- 3. Génération de la Carte ---
m = folium.Map(tiles="CartoDB positron")

# Préparation des limites pour le zoom auto
locations = df[['latitude', 'longitude']].values.tolist()

# --- HTML de l'étiquette ---
for _, row in df.iterrows():
    label_html = f"""
    <div style="
    font-family: Arial, sans-serif;
    text-align: center; width: 150px;
    background: rgba(255,255,255,0.95); border-radius: 8px; padding: 8px;
    box-shadow: 0 2px 5px rgba(0,0,0,0.2); border: 1px solid #ddd;
    ">
        <strong style="color: #2c3e50; font-size: 14px;">{row['first_name']} {row['last_name']}</strong><br>
        <div style="color: #7f8c8d; font-size: 11px; margin: 4px 0;">📍 {row['city'].upper()}</div>
        <div style="color: #27ae60; font-weight: bold; font-size: 12px;">★ Score: {row['nice_score']}</div>
    </div>
    """

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        icon=folium.Icon(color="green", icon="star", prefix='fa'),
        tooltip=folium.Tooltip(label_html,
        permanent=True, direction='top',
        offset=[0, -40],
        sticky=False)
    ).add_to(m)

# Cadrage automatique
if len(locations) > 0:
    m.fit_bounds(locations, padding=[100, 100])

m
# Out:
# ------------- 🏆 TOP 3 KIDS 2025 -------------
#   first_name           city   latitude   longitude
# 0     Astrid          Paris  48.875872    2.370207
# 1       Isha        Beijing  39.911644  116.391617
# 2       Omar  San Francisco  37.790593 -122.412131
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f393f8764776ef3436195875cf15137a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f393f8764776ef3436195875cf15137a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f393f8764776ef3436195875cf15137a = L.map(
#                 &quot;map_f393f8764776ef3436195875cf15137a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef493bd0c1ebebc5c1dd6a1688308938 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef493bd0c1ebebc5c1dd6a1688308938.addTo(map_f393f8764776ef3436195875cf15137a);
#
#
#             var marker_227c851834d871faf3e2d8da56418ab0 = L.marker(
#                 [48.875872202602984, 2.37020683674042],
#                 {
# }
#             ).addTo(map_f393f8764776ef3436195875cf15137a);
#
#
#             var icon_a35e7fdf6db7749a6a2530cce9b8c875 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_227c851834d871faf3e2d8da56418ab0.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;div style=&quot;
#     font-family: Arial, sans-serif;
#     text-align: center; width: 150px;
#     background: rgba(255,255,255,0.95); border-radius: 8px; padding: 8px;
#     box-shadow: 0 2px 5px rgba(0,0,0,0.2); border: 1px solid #ddd;
#     &quot;&gt;
#         &lt;strong style=&quot;color: #2c3e50; font-size: 14px;&quot;&gt;Astrid Lopez&lt;/strong&gt;&lt;br&gt;
#         &lt;div style=&quot;color: #7f8c8d; font-size: 11px; margin: 4px 0;&quot;&gt;📍 PARIS&lt;/div&gt;
#         &lt;div style=&quot;color: #27ae60; font-weight: bold; font-size: 12px;&quot;&gt;★ Score: 100.0&lt;/div&gt;
#     &lt;/div&gt;
#
#                  &lt;/div&gt;`,
#                 {
#   &quot;permanent&quot;: true,
#   &quot;direction&quot;: &quot;top&quot;,
#   &quot;offset&quot;: [
# 0,
# -40,
# ],
#   &quot;sticky&quot;: false,
# }
#             );
#
#
#                 marker_227c851834d871faf3e2d8da56418ab0.setIcon(icon_a35e7fdf6db7749a6a2530cce9b8c875);
#
#
#             var marker_a6c76e867cd6ab1374a9b20ac56b1d2c = L.marker(
#                 [39.91164444766509, 116.39161725675824],
#                 {
# }
#             ).addTo(map_f393f8764776ef3436195875cf15137a);
#
#
#             var icon_ae4e456d2ba7a3220576d17ba408126b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_a6c76e867cd6ab1374a9b20ac56b1d2c.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;div style=&quot;
#     font-family: Arial, sans-serif;
#     text-align: center; width: 150px;
#     background: rgba(255,255,255,0.95); border-radius: 8px; padding: 8px;
#     box-shadow: 0 2px 5px rgba(0,0,0,0.2); border: 1px solid #ddd;
#     &quot;&gt;
#         &lt;strong style=&quot;color: #2c3e50; font-size: 14px;&quot;&gt;Isha Takahashi&lt;/strong&gt;&lt;br&gt;
#         &lt;div style=&quot;color: #7f8c8d; font-size: 11px; margin: 4px 0;&quot;&gt;📍 BEIJING&lt;/div&gt;
#         &lt;div style=&quot;color: #27ae60; font-weight: bold; font-size: 12px;&quot;&gt;★ Score: 100.0&lt;/div&gt;
#     &lt;/div&gt;
#
#                  &lt;/div&gt;`,
#                 {
#   &quot;permanent&quot;: true,
#   &quot;direction&quot;: &quot;top&quot;,
#   &quot;offset&quot;: [
# 0,
# -40,
# ],
#   &quot;sticky&quot;: false,
# }
#             );
#
#
#                 marker_a6c76e867cd6ab1374a9b20ac56b1d2c.setIcon(icon_ae4e456d2ba7a3220576d17ba408126b);
#
#
#             var marker_f8273c67d95c3d260d8be376ca481f56 = L.marker(
#                 [37.790593039065875, -122.41213060423046],
#                 {
# }
#             ).addTo(map_f393f8764776ef3436195875cf15137a);
#
#
#             var icon_5d6490044999d515a0403e90f518fc2e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot
